# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Table to retrace emails for when the new survey must be sent out

# %%
analysis_df = pd.read_csv("dss_data22nov.csv")
contact_df = analysis_df[["subject", "email"]].copy()
contact_df = contact_df.dropna(subset=["email"])
contact_group2 = analysis_df[analysis_df["group"] == 2][["subject", "email"]].dropna(subset=["email"])
contact_group2
# Out:
#       subject                                 email
# 0   anonymous             pieter.drabbe@hotmail.com
# 3        S105               kittytail@hotmail.co.uk
# 4        S106               harryhall3698@gmail.com
# 5        S107  l.j.vanvoorden@tilburguniversity.edu
# 13       S128    r.s.kramer_1@tilburguniversity.edu
# 14       S129    j.m.spuesens@tilburguniversity.edu
# 16       S137                Alettakramer@gmail.com
# 17       S139                   R.kramer@genexis.eu
# 18       S140             Kramer.marijke@kpnmail.nl
# 19       S148          roosvanvoorden2004@gmail.com
# 20       S150        r.w.mast@tilburguniversity.edu
# 24       S159                nijdamgerben@gmail.com
# 26       S161     f.vdnbrekel@tilburguniversity.edu
# 27       S169                  jackmeijer28@live.nl
# 28       S171            ambervdheuvel007@gmail.com
# 30       S174                   tranjaney@gmail.com
# 31       S178             bloemvdbrekel@outlook.com
# 33       S182            woutvdveldenspam@gmail.com
# 34       S183                    Veldenk2@gmail.com
# 35       S184                   feevdbrekel@live.nl
# 36       S185          julemackenbach2002@gmail.com
# 37       S186            mielvandenbrekel@gmail.com
# 80         S9       f.franken@tilburguniversity.edu

# %% [markdown]
# Load the data

# %%
ratings_path = "dss_data22nov.csv"   # survey data
songs_path   = "candDSS.csv"         # song features

# %%
df_ratings = pd.read_csv(ratings_path)
df_songs   = pd.read_csv(songs_path)

# %% [markdown]
# We keep only group 2 participants

# %%
df_g2 = df_ratings[df_ratings["group"] == 2].copy()

# %% [markdown]
# Sorting the columns

# %%
rating_cols = [
    c for c in df_g2.columns
    if c.startswith("s") and c.endswith("r") and c[1:-1].isdigit()
]

fam_cols = [
    c for c in df_g2.columns
    if c.startswith("f") and c[1:].isdigit()
]

print("Number of participants", len(df_g2))
print("Number of rating columns:", len(rating_cols))
# Out:
# Number of participants 23
# Number of rating columns: 60

# %% [markdown]
# Clean data and adjust format

# %%
for col in rating_cols:
    df_g2[col] = pd.to_numeric(df_g2[col], errors="coerce")

for col in fam_cols:
    df_g2[col] = df_g2[col].replace("new", "new")

# %% [markdown]
# Extract Song IDs

# %%
long_ratings = df_g2.melt(
    id_vars=["subject"],          
    value_vars=rating_cols,  
    var_name="rating_col",
    value_name="rating"
)

# Drop NAs
long_ratings = long_ratings.dropna(subset=["rating"])

# Extract song ID from column name
long_ratings["song_id"] = (
    long_ratings["rating_col"]
    .str.extract(r"s(\d+)r")
    .astype(int)
)

# %%
df_long = long_ratings

# %% [markdown]
# Make a new dataframe with song features

# %%
song_features = df_songs[[
    "id", "genre_allmusic", "trackname",
    "danceability", "valence", "energy",
    "acousticness", "instrumentalness",
    "speechiness", "liveness",
    "tempo", "loudness", "density"
]].rename(columns={"id": "song_id"})

# %%
analysis_df = df_long.merge(
    song_features,
    on="song_id",
    how="left"
)

# %% [markdown]
# Sort the dataframe by user

# %%
analysis_df = analysis_df.sort_values(by="subject").reset_index(drop=True)

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

analysis_df
# Out:
#        subject rating_col  rating  song_id genre_allmusic  \
# 0         S105        s2r     3.0        2       pop-rock
# 1         S105        s1r     5.0        1       pop-rock
# 2         S105       s30r     3.0       30        country
# 3         S105       s21r     3.0       21        country
# 4         S105       s57r     5.0       57            rnb
# 5         S105       s50r     1.0       50            rap
# 6         S105       s20r     5.0       20      classical
# 7         S105        s6r     4.0        6       pop-rock
# 8         S105       s55r     3.0       55            rnb
# 9         S105       s26r     4.0       26        country
# 10        S105       s36r     2.0       36     electronic
# 11        S105       s49r     2.0       49            rap
# 12        S105       s22r     3.0       22        country
# 13        S105       s12r     3.0       12      classical
# 14        S105       s33r     3.0       33     electronic
# 15        S106       s38r     3.0       38     electronic
# 16        S106       s10r     5.0       10       pop-rock
# 17        S106       s37r     3.0       37     electronic
# 18        S106       s17r     4.0       17      classical
# 19        S106       s21r     4.0       21        country
# 20        S106       s54r     2.0       54            rnb
# 21        S106       s42r     5.0       42            rap
# 22        S106       s35r     1.0       35     electronic
# 23        S106       s51r     3.0       51            rnb
# 24        S106       s14r     4.0       14      classical
# 25        S106       s33r     3.0       33     electronic
# 26        S106        s6r     4.0        6       pop-rock
# 27        S106       s52r     4.0       52            rnb
# 28        S106        s4r     5.0        4       pop-rock
# 29        S106       s59r     4.0       59            rnb
# 30        S107       s35r     1.0       35     electronic
# 31        S107       s46r     3.0       46            rap
# 32        S107       s15r     3.0       15      classical
# 33        S107       s34r     2.0       34     electronic
# 34        S107       s58r     3.0       58            rnb
# 35        S107        s2r     4.0        2       pop-rock
# 36        S107        s6r     2.0        6       pop-rock
# 37        S107        s3r     4.0        3       pop-rock
# 38        S107       s42r     1.0       42            rap
# 39        S107       s51r     4.0       51            rnb
# 40        S107       s11r     2.0       11      classical
# 41        S107       s16r     2.0       16      classical
# 42        S107       s18r     2.0       18      classical
# 43        S107       s13r     3.0       13      classical
# 44        S107       s47r     2.0       47            rap
# 45        S128        s6r     4.0        6       pop-rock
# 46        S128        s4r     4.0        4       pop-rock
# 47        S128       s10r     3.0       10       pop-rock
# 48        S128       s30r     2.0       30        country
# 49        S128       s41r     3.0       41            rap
# 50        S128       s47r     3.0       47            rap
# 51        S128       s57r     1.0       57            rnb
# 52        S128       s18r     1.0       18      classical
# 53        S128       s11r     1.0       11      classical
# 54        S128       s28r     2.0       28        country
# 55        S128       s19r     2.0       19      classical
# 56        S128       s23r     4.0       23        country
# 57        S128       s32r     2.0       32     electronic
# 58        S128       s34r     2.0       34     electronic
# 59        S128       s38r     4.0       38     electronic
# 60        S129       s38r     3.0       38     electronic
# 61        S129       s25r     1.0       25        country
# 62        S129       s14r     2.0       14      classical
# 63        S129       s50r     5.0       50            rap
# 64        S129       s24r     2.0       24        country
# 65        S129       s42r     3.0       42            rap
# 66        S129       s30r     1.0       30        country
# 67        S129       s46r     4.0       46            rap
# 68        S129       s41r     1.0       41            rap
# 69        S129       s28r     1.0       28        country
# 70        S129       s34r     1.0       34     electronic
# 71        S129       s13r     2.0       13      classical
# 72        S129        s4r     1.0        4       pop-rock
# 73        S129        s3r     3.0        3       pop-rock
# 74        S129       s29r     2.0       29        country
# 75        S137       s16r     2.0       16      classical
# 76        S137       s32r     4.0       32     electronic
# 77        S137       s51r     2.0       51            rnb
# 78        S137        s3r     3.0        3       pop-rock
# 79        S137        s5r     2.0        5       pop-rock
# 80        S137       s26r     3.0       26        country
# 81        S137       s36r     2.0       36     electronic
# 82        S137       s41r     3.0       41            rap
# 83        S137       s46r     3.0       46            rap
# 84        S137       s50r     3.0       50            rap
# 85        S137       s28r     3.0       28        country
# 86        S137       s53r     2.0       53            rnb
# 87        S137       s15r     2.0       15      classical
# 88        S137        s1r     3.0        1       pop-rock
# 89        S137        s2r     2.0        2       pop-rock
# 90        S139       s59r     1.0       59            rnb
# 91        S139       s52r     1.0       52            rnb
# 92        S139       s19r     2.0       19      classical
# 93        S139       s29r     2.0       29        country
# 94        S139       s10r     3.0       10       pop-rock
# 95        S139        s6r     5.0        6       pop-rock
# 96        S139       s31r     2.0       31     electronic
# 97        S139       s56r     1.0       56            rnb
# 98        S139       s46r     1.0       46            rap
# 99        S139       s18r     2.0       18      classical
# 100       S139        s1r     2.0        1       pop-rock
# 101       S139       s49r     2.0       49            rap
# 102       S139       s11r     3.0       11      classical
# 103       S139       s16r     1.0       16      classical
# 104       S139        s2r     2.0        2       pop-rock
# 105       S140       s49r     3.0       49            rap
# 106       S140       s33r     1.0       33     electronic
# 107       S140        s5r     2.0        5       pop-rock
# 108       S140       s52r     3.0       52            rnb
# 109       S140        s4r     4.0        4       pop-rock
# 110       S140       s27r     2.0       27        country
# 111       S140       s59r     3.0       59            rnb
# 112       S140       s10r     2.0       10       pop-rock
# 113       S140       s55r     2.0       55            rnb
# 114       S140       s17r     3.0       17      classical
# 115       S140       s15r     3.0       15      classical
# 116       S140       s14r     4.0       14      classical
# 117       S140       s32r     1.0       32     electronic
# 118       S140       s54r     1.0       54            rnb
# 119       S140       s51r     3.0       51            rnb
# 120       S148       s36r     1.0       36     electronic
# 121       S148       s56r     3.0       56            rnb
# 122       S148       s22r     3.0       22        country
# 123       S148       s60r     3.0       60            rnb
# 124       S148        s1r     4.0        1       pop-rock
# 125       S148       s42r     4.0       42            rap
# 126       S148       s24r     2.0       24        country
# 127       S148       s15r     2.0       15      classical
# 128       S148       s11r     1.0       11      classical
# 129       S148       s40r     2.0       40     electronic
# 130       S148       s53r     3.0       53            rnb
# 131       S148       s13r     2.0       13      classical
# 132       S148       s10r     4.0       10       pop-rock
# 133       S148        s5r     4.0        5       pop-rock
# 134       S148       s32r     1.0       32     electronic
# 135       S150       s11r     1.0       11      classical
# 136       S150       s56r     4.0       56            rnb
# 137       S150       s17r     3.0       17      classical
# 138       S150        s7r     2.0        7       pop-rock
# 139       S150       s53r     4.0       53            rnb
# 140       S150        s1r     4.0        1       pop-rock
# 141       S150       s35r     3.0       35     electronic
# 142       S150       s34r     2.0       34     electronic
# 143       S150       s13r     1.0       13      classical
# 144       S150        s6r     1.0        6       pop-rock
# 145       S150        s3r     4.0        3       pop-rock
# 146       S150       s38r     2.0       38     electronic
# 147       S150       s45r     4.0       45            rap
# 148       S150        s9r     2.0        9       pop-rock
# 149       S150       s54r     4.0       54            rnb
# 150       S159       s51r     4.0       51            rnb
# 151       S159       s19r     4.0       19      classical
# 152       S159       s28r     1.0       28        country
# 153       S159       s10r     4.0       10       pop-rock
# 154       S159       s34r     3.0       34     electronic
# 155       S159       s26r     2.0       26        country
# 156       S159        s3r     4.0        3       pop-rock
# 157       S159       s60r     4.0       60            rnb
# 158       S159        s1r     4.0        1       pop-rock
# 159       S159       s20r     2.0       20      classical
# 160       S159       s14r     3.0       14      classical
# 161       S159       s42r     5.0       42            rap
# 162       S159       s33r     3.0       33     electronic
# 163       S159       s25r     1.0       25        country
# 164       S159       s31r     5.0       31     electronic
# 165       S161       s30r     3.0       30        country
# 166       S161       s58r     5.0       58            rnb
# 167       S161       s33r     2.0       33     electronic
# 168       S161        s8r     5.0        8       pop-rock
# 169       S161       s36r     2.0       36     electronic
# 170       S161       s15r     4.0       15      classical
# 171       S161        s7r     1.0        7       pop-rock
# 172       S161       s60r     3.0       60            rnb
# 173       S161        s3r     3.0        3       pop-rock
# 174       S161       s48r     3.0       48            rap
# 175       S161       s47r     3.0       47            rap
# 176       S161       s29r     3.0       29        country
# 177       S161       s38r     3.0       38     electronic
# 178       S161       s17r     4.0       17      classical
# 179       S161       s53r     3.0       53            rnb
# 180       S169       s31r     2.0       31     electronic
# 181       S169       s13r     3.0       13      classical
# 182       S169       s15r     2.0       15      classical
# 183       S169        s7r     2.0        7       pop-rock
# 184       S169       s60r     3.0       60            rnb
# 185       S169       s44r     2.0       44            rap
# 186       S169       s21r     2.0       21        country
# 187       S169       s39r     2.0       39     electronic
# 188       S169       s58r     4.0       58            rnb
# 189       S169       s33r     1.0       33     electronic
# 190       S169       s30r     3.0       30        country
# 191       S169        s9r     2.0        9       pop-rock
# 192       S169       s40r     1.0       40     electronic
# 193       S169       s10r     3.0       10       pop-rock
# 194       S169        s4r     3.0        4       pop-rock
# 195       S171        s7r     2.0        7       pop-rock
# 196       S171       s41r     2.0       41            rap
# 197       S171       s21r     4.0       21        country
# 198       S171       s25r     2.0       25        country
# 199       S171       s52r     4.0       52            rnb
# 200       S171       s27r     1.0       27        country
# 201       S171       s59r     5.0       59            rnb
# 202       S171       s12r     2.0       12      classical
# 203       S171       s47r     4.0       47            rap
# 204       S171       s48r     5.0       48            rap
# 205       S171       s39r     2.0       39     electronic
# 206       S171       s31r     2.0       31     electronic
# 207       S171       s13r     2.0       13      classical
# 208       S171       s32r     3.0       32     electronic
# 209       S171        s6r     4.0        6       pop-rock
# 210       S174       s35r     2.0       35     electronic
# 211       S174       s51r     3.0       51            rnb
# 212       S174       s31r     3.0       31     electronic
# 213       S174       s52r     3.0       52            rnb
# 214       S174       s21r     4.0       21        country
# 215       S174       s57r     3.0       57            rnb
# 216       S174       s26r     2.0       26        country
# 217       S174        s2r     4.0        2       pop-rock
# 218       S174       s28r     1.0       28        country
# 219       S174       s50r     3.0       50            rap
# 220       S174       s54r     2.0       54            rnb
# 221       S174       s29r     1.0       29        country
# 222       S174       s46r     2.0       46            rap
# 223       S174       s40r     2.0       40     electronic
# 224       S174       s18r     3.0       18      classical
# 225       S178        s6r     1.0        6       pop-rock
# 226       S178       s43r     2.0       43            rap
# 227       S178       s60r     3.0       60            rnb
# 228       S178       s22r     3.0       22        country
# 229       S178        s3r     2.0        3       pop-rock
# 230       S178       s25r     1.0       25        country
# 231       S178       s23r     2.0       23        country
# 232       S178       s11r     1.0       11      classical
# 233       S178       s16r     2.0       16      classical
# 234       S178       s35r     1.0       35     electronic
# 235       S178       s41r     3.0       41            rap
# 236       S178       s30r     2.0       30        country
# 237       S178       s47r     2.0       47            rap
# 238       S178       s38r     4.0       38     electronic
# 239       S178       s27r     1.0       27        country
# 240       S182       s17r     1.0       17      classical
# 241       S182       s27r     2.0       27        country
# 242       S182        s2r     3.0        2       pop-rock
# 243       S182       s16r     1.0       16      classical
# 244       S182       s19r     1.0       19      classical
# 245       S182       s41r     2.0       41            rap
# 246       S182       s45r     1.0       45            rap
# 247       S182       s22r     2.0       22        country
# 248       S182       s21r     2.0       21        country
# 249       S182       s50r     4.0       50            rap
# 250       S182        s6r     1.0        6       pop-rock
# 251       S182       s10r     2.0       10       pop-rock
# 252       S182       s47r     1.0       47            rap
# 253       S182       s42r     3.0       42            rap
# 254       S182       s52r     3.0       52            rnb
# 255       S183       s52r     2.0       52            rnb
# 256       S183       s25r     3.0       25        country
# 257       S183       s21r     2.0       21        country
# 258       S183        s1r     5.0        1       pop-rock
# 259       S183        s7r     4.0        7       pop-rock
# 260       S183       s34r     3.0       34     electronic
# 261       S183       s26r     3.0       26        country
# 262       S183       s19r     1.0       19      classical
# 263       S183       s32r     1.0       32     electronic
# 264       S183       s31r     1.0       31     electronic
# 265       S183       s15r     4.0       15      classical
# 266       S183       s22r     2.0       22        country
# 267       S183       s27r     3.0       27        country
# 268       S183       s57r     3.0       57            rnb
# 269       S183       s41r     2.0       41            rap
# 270       S184       s10r     1.0       10       pop-rock
# 271       S184       s18r     3.0       18      classical
# 272       S184        s8r     4.0        8       pop-rock
# 273       S184       s19r     2.0       19      classical
# 274       S184       s48r     4.0       48            rap
# 275       S184       s15r     1.0       15      classical
# 276       S184       s33r     1.0       33     electronic
# 277       S184       s24r     4.0       24        country
# 278       S184       s21r     1.0       21        country
# 279       S184        s4r     3.0        4       pop-rock
# 280       S184       s36r     2.0       36     electronic
# 281       S184       s57r     4.0       57            rnb
# 282       S184       s58r     5.0       58            rnb
# 283       S184       s42r     1.0       42            rap
# 284       S184       s29r     2.0       29        country
# 285       S185       s49r     5.0       49            rap
# 286       S185       s20r     1.0       20      classical
# 287       S185       s12r     1.0       12      classical
# 288       S185       s17r     1.0       17      classical
# 289       S185        s4r     4.0        4       pop-rock
# 290       S185       s32r     1.0       32     electronic
# 291       S185       s54r     4.0       54            rnb
# 292       S185       s59r     4.0       59            rnb
# 293       S185       s26r     1.0       26        country
# 294       S185       s16r     1.0       16      classical
# 295       S185       s57r     2.0       57            rnb
# 296       S185       s11r     1.0       11      classical
# 297       S185       s24r     3.0       24        country
# 298       S185       s35r     2.0       35     electronic
# 299       S185       s23r     3.0       23        country
# 300       S186       s25r     3.0       25        country
# 301       S186       s40r     5.0       40     electronic
# 302       S186        s3r     4.0        3       pop-rock
# 303       S186       s44r     5.0       44            rap
# 304       S186       s18r     4.0       18      classical
# 305       S186       s37r     4.0       37     electronic
# 306       S186       s58r     4.0       58            rnb
# 307       S186       s16r     3.0       16      classical
# 308       S186       s28r     2.0       28        country
# 309       S186        s1r     5.0        1       pop-rock
# 310       S186       s29r     2.0       29        country
# 311       S186        s7r     3.0        7       pop-rock
# 312       S186       s38r     3.0       38     electronic
# 313       S186       s27r     3.0       27        country
# 314       S186        s8r     5.0        8       pop-rock
# 315         S9       s11r     4.0       11      classical
# 316         S9       s31r     2.0       31     electronic
# 317         S9       s26r     4.0       26        country
# 318         S9       s60r     3.0       60            rnb
# 319         S9       s35r     3.0       35     electronic
# 320         S9       s48r     3.0       48            rap
# 321         S9        s5r     3.0        5       pop-rock
# 322         S9       s23r     4.0       23        country
# 323         S9        s8r     4.0        8       pop-rock
# 324         S9        s7r     2.0        7       pop-rock
# 325         S9       s12r     4.0       12      classical
# 326         S9       s53r     3.0       53            rnb
# 327         S9       s42r     1.0       42            rap
# 328         S9        s9r     3.0        9       pop-rock
# 329         S9       s25r     3.0       25        country
# 330  anonymous        s5r     2.0        5       pop-rock
# 331  anonymous        s2r     4.0        2       pop-rock
# 332  anonymous       s55r     2.0       55            rnb
# 333  anonymous       s50r     2.0       50            rap
# 334  anonymous       s29r     2.0       29        country
# 335  anonymous       s58r     4.0       58            rnb
# 336  anonymous        s1r     4.0        1       pop-rock
# 337  anonymous       s38r     2.0       38     electronic
# 338  anonymous       s36r     2.0       36     electronic
# 339  anonymous       s37r     3.0       37     electronic
# 340  anonymous       s54r     3.0       54            rnb
# 341  anonymous        s7r     3.0        7       pop-rock
# 342  anonymous        s4r     4.0        4       pop-rock
# 343  anonymous       s52r     3.0       52            rnb
# 344  anonymous       s22r     3.0       22        country
#
#                                              trackname  danceability  valence  \
# 0                         Beast Of Burden - Remastered         0.783   0.8850
# 1    More Than A Woman - From "Saturday Night Fever...         0.601   0.6730
# 2                                          I'm Alright         0.676   0.5910
# 3                         Blue Eyes Crying In the Rain         0.626   0.4180
# 4                                   A Teenager In Love         0.555   0.6190
# 5                   You Know How We Do It - Remastered         0.747   0.6010
# 6                                             Epilogue         0.190   0.0786
# 7                                  She Sells Sanctuary         0.550   0.4190
# 8                                        Have You Ever         0.698   0.2750
# 9                                               Aw Naw         0.652   0.4910
# 10                                                Jóga         0.226   0.2280
# 11               Young, Wild & Free (feat. Bruno Mars)         0.553   0.5510
# 12                                                Babe         0.535   0.6640
# 13   Bassoon Concerto in B-Flat Major, K. 191: II. ...         0.137   0.0666
# 14                                         Arguru 2k19         0.702   0.2840
# 15                                               IZ-US         0.581   0.3150
# 16                           Ramble On - 1990 Remaster         0.468   0.8860
# 17                                             Trigger         0.570   0.3780
# 18                                      Gabriel's Oboe         0.233   0.0675
# 315   -13.384     7.687642
# 316   -14.475    20.144158
# 317    -3.746     2.987505
# 318   -12.585     4.909530
# 319    -5.694   485.379973
# 320    -5.579     0.339487
# 321   -10.059     1.943766
# 322    -4.145     4.988260
# 323    -7.040    21.440436
# 324    -3.579     3.761015
# 325   -28.639  1112.230131
# 326    -2.766     3.104600
# 327    -6.638    21.337603
# 328    -5.270    13.365649
# 329    -5.703    11.880662
# 330   -10.059     1.943766
# 331    -3.864     3.247493
# 332    -6.246     0.446351
# 333   -10.523    25.360962
# 334    -9.276     7.432218
# 335    -7.006     9.392343
# 336    -6.240    19.365283
# 337   -14.519     4.226005
# 338    -6.327     0.054892
# 339    -7.041     3.525144
# 340    -4.865    15.849489
# 341    -3.579     3.761015
# 342    -7.957    18.645021
# 343    -6.286     0.040596
# 344    -3.292     8.649252

# %% [markdown]
# Make user profiles

# %% [markdown]
# We add an extra column that states a user's opinion on the song based on their rating

# %%
analysis_df["like_label"] = np.where(
    analysis_df["rating"] >= 4, "like",
    np.where(analysis_df["rating"] <= 2, "dislike", "neutral")
)

analysis_df["like_label"].value_counts()
# Out:
# like_label
# dislike    159
# neutral     97
# like        89
# Name: count, dtype: int64

# %%
analysis_df.head()
# Out:
#   subject rating_col  rating  song_id genre_allmusic  \
# 0    S105        s2r     3.0        2       pop-rock
# 1    S105        s1r     5.0        1       pop-rock
# 2    S105       s30r     3.0       30        country
# 3    S105       s21r     3.0       21        country
# 4    S105       s57r     5.0       57            rnb
#
#                                            trackname  danceability  valence  \
# 0                       Beast Of Burden - Remastered         0.783    0.885
# 1  More Than A Woman - From "Saturday Night Fever...         0.601    0.673
# 2                                        I'm Alright         0.676    0.591
# 3                       Blue Eyes Crying In the Rain         0.626    0.418
# 4                                 A Teenager In Love         0.555    0.619
#
#    energy  acousticness  instrumentalness  speechiness  liveness    tempo  \
# 0   0.878         0.390          0.000778       0.0308    0.0426  100.626
# 1   0.703         0.175          0.000084       0.0379    0.5710  106.164
# 2   0.733         0.191          0.000000       0.0294    0.1920   98.234
# 3   0.040         0.928          0.001780       0.0405    0.1100  117.136
# 4   0.377         0.671          0.000000       0.0295    0.1280   78.986
#
#    loudness    density like_label
# 0    -3.864   3.247493    neutral
# 1    -6.240  19.365283       like
# 2    -7.745  10.100652    neutral
# 3   -19.994   2.241434    neutral
# 4    -9.123  10.099300       like

# %% [markdown]
# We use the new like column to set up the user profiles

# %%
feature_cols = [
    "danceability",
    "valence",
    "energy",
    "acousticness",
    "instrumentalness",
    "speechiness",
    "liveness",
    "tempo",
    "loudness",
    "density"
]

# %%
liked = analysis_df[analysis_df["like_label"] == "like"]

user_profile_like = (
    liked.groupby("subject")[feature_cols]
         .mean()
         .reset_index()
         .rename(columns=lambda c: c + "_like" if c in feature_cols else c)
)

# %%
user_profile_like.head()
# Out:
#   subject  danceability_like  valence_like  energy_like  acousticness_like  \
# 0    S105           0.509600      0.456120     0.555580           0.376981
# 1    S106           0.589000      0.457700     0.524267           0.386165
# 2    S107           0.589333      0.614967     0.591667           0.486667
# 3    S128           0.542250      0.395750     0.624500           0.046751
# 4    S129           0.703500      0.681000     0.613500           0.247350
#
#    instrumentalness_like  speechiness_like  liveness_like  tempo_like  \
# 0               0.196617          0.033040       0.196240     106.915
# 1               0.298525          0.047678       0.139167     111.059
# 2               0.000328          0.035467       0.230200     105.064
# 3               0.438521          0.033100       0.120825     114.940
# 4               0.026850          0.121850       0.176500      91.074
#
#    loudness_like  density_like
# 0      -9.838600     65.167345
# 1     -11.940556    135.614987
# 2      -9.755000      7.867858
# 3      -8.826250     43.017828
# 4      -8.140500     14.012684

# %% [markdown]
# The user profiles now show the average scores users had for each feature in songs they liked

# %%
analysis_df = analysis_df.merge(user_profile_like, on="subject", how="left")
analysis_df.head()
# Out:
#   subject rating_col  rating  song_id genre_allmusic  \
# 0    S105        s2r     3.0        2       pop-rock
# 1    S105        s1r     5.0        1       pop-rock
# 2    S105       s30r     3.0       30        country
# 3    S105       s21r     3.0       21        country
# 4    S105       s57r     5.0       57            rnb
#
#                                            trackname  danceability  valence  \
# 0                       Beast Of Burden - Remastered         0.783    0.885
# 1  More Than A Woman - From "Saturday Night Fever...         0.601    0.673
# 2                                        I'm Alright         0.676    0.591
# 3                       Blue Eyes Crying In the Rain         0.626    0.418
# 4                                 A Teenager In Love         0.555    0.619
#
#    energy  acousticness  instrumentalness  speechiness  liveness    tempo  \
# 0   0.878         0.390          0.000778       0.0308    0.0426  100.626
# 1   0.703         0.175          0.000084       0.0379    0.5710  106.164
# 2   0.733         0.191          0.000000       0.0294    0.1920   98.234
# 3   0.040         0.928          0.001780       0.0405    0.1100  117.136
# 4   0.377         0.671          0.000000       0.0295    0.1280   78.986
#
#    loudness    density like_label  danceability_like  valence_like  \
# 0    -3.864   3.247493    neutral             0.5096       0.45612
# 1    -6.240  19.365283       like             0.5096       0.45612
# 2    -7.745  10.100652    neutral             0.5096       0.45612
# 3   -19.994   2.241434    neutral             0.5096       0.45612
# 4    -9.123  10.099300       like             0.5096       0.45612
#
#    energy_like  acousticness_like  instrumentalness_like  speechiness_like  \
# 0      0.55558           0.376981               0.196617           0.03304
# 1      0.55558           0.376981               0.196617           0.03304
# 2      0.55558           0.376981               0.196617           0.03304
# 3      0.55558           0.376981               0.196617           0.03304
# 4      0.55558           0.376981               0.196617           0.03304
#
#    liveness_like  tempo_like  loudness_like  density_like
# 0        0.19624     106.915        -9.8386     65.167345
# 1        0.19624     106.915        -9.8386     65.167345
# 2        0.19624     106.915        -9.8386     65.167345
# 3        0.19624     106.915        -9.8386     65.167345
# 4        0.19624     106.915        -9.8386     65.167345

# %%
top_genre_per_user = (
    analysis_df[analysis_df["like_label"] == "like"]
      .groupby("subject")["genre_allmusic"]
      .agg(lambda x: x.mode().iloc[0])
      .reset_index()
      .rename(columns={"genre_allmusic": "preferred_genre"})
)

analysis_df = analysis_df.merge(top_genre_per_user, on="subject", how="left")

# %%
analysis_df.to_csv("cleaned_musicdata.csv", index=False)

# %% [markdown]
# Now it's time to generate recommendations. We decided to generate 8 recommendations per user. 2 of their preferred genre with similar characteristics to what they like. 2 of their preferred genre with characteristics farthest from what they like. 2 of genres that are not their preferred genre with similar characteristics to what they like. And 2 of their non-preferred genres with characteristics farthest from what they like.
#
# The distance comparison was made from a combination of danceability, valence, and energy, as we found these three characteristics to be important ones in assessing how much someone would like a song.

# %%
N = 2  # how many similar songs per subject

feat_cols = ["danceability", "valence", "energy"]
like_cols = ["danceability_like", "valence_like", "energy_like"]

# %% [markdown]
# We loop over all users, generating these sets of 2 recommendations

# %%
rows = []
for subj in analysis_df["subject"].unique():
    # Preferred genre for this subject
    preferred_genre = analysis_df.loc[
        analysis_df["subject"] == subj, "preferred_genre"
    ].iloc[0]
    
    # Subject's like profile
    user_pref = analysis_df.loc[
        analysis_df["subject"] == subj, like_cols
    ].iloc[0]
    
    # Songs in that genre
    songs_same_genre = df_songs[df_songs["genre_allmusic"] == preferred_genre].copy()
    
    # Remove songs the subject already rated
    rated_songs = set(
        analysis_df.loc[analysis_df["subject"] == subj, "song_id"].tolist()
    )
    songs_same_genre = songs_same_genre[
        ~songs_same_genre["id"].isin(rated_songs)
    ].copy()
    
    if songs_same_genre.empty:
        continue  # nothing to recommend for this subject
    
    # Compute distance
    diffs = songs_same_genre[feat_cols].values - user_pref.values
    songs_same_genre["distance"] = np.linalg.norm(diffs, axis=1)
    
    # Take N most similar songs
    most_similar = songs_same_genre.sort_values("distance").head(N)
    
    # Store only the columns you want
    for _, row in most_similar.iterrows():
        rows.append({
            "subject": subj,
            "genre_allmusic": row["genre_allmusic"],
            "trackname": row["trackname"],
            "bucket": "same_genre_similar"
        })

# Final dataframe with only the requested columns
recs_same_genre_similar = pd.DataFrame(rows)

# %%
rows = []
for subj in analysis_df["subject"].unique():
    
    # Subject's preferred genre
    preferred_genre = analysis_df.loc[
        analysis_df["subject"] == subj, "preferred_genre"
    ].iloc[0]
    
    # Subject's like profile
    user_pref = analysis_df.loc[
        analysis_df["subject"] == subj, like_cols
    ].iloc[0]
    
    # Songs not in preferred genre
    songs_diff_genre = df_songs[df_songs["genre_allmusic"] != preferred_genre].copy()
    
    # Remove songs already rated
    rated_songs = set(
        analysis_df.loc[analysis_df["subject"] == subj, "song_id"].tolist()
    )
    songs_diff_genre = songs_diff_genre[
        ~songs_diff_genre["id"].isin(rated_songs)
    ].copy()
    
    if songs_diff_genre.empty:
        continue
    
    # Compute distance to user’s preference
    diffs = songs_diff_genre[feat_cols].values - user_pref.values
    songs_diff_genre["distance"] = np.linalg.norm(diffs, axis=1)
    
    # Pick N most similar (smallest distance)
    most_similar = songs_diff_genre.sort_values("distance").head(N)
    
    # Keep only the required columns
    for _, row in most_similar.iterrows():
        rows.append({
            "subject": subj,
            "genre_allmusic": row["genre_allmusic"],
            "trackname": row["trackname"],
            "bucket": "diff_genre_similar"
        })

# Final dataframe
recs_diff_genre_similar = pd.DataFrame(rows)

# %%
rows = []
for subj in analysis_df["subject"].unique():
    
    # Subject's preferred genre
    preferred_genre = analysis_df.loc[
        analysis_df["subject"] == subj, "preferred_genre"
    ].iloc[0]
    
    # Subject's like profile
    user_pref = analysis_df.loc[
        analysis_df["subject"] == subj, like_cols
    ].iloc[0]
    
    # Songs in the preferred genre
    songs_same_genre = df_songs[df_songs["genre_allmusic"] == preferred_genre].copy()
    
    # Remove songs already rated
    rated_songs = set(
        analysis_df.loc[analysis_df["subject"] == subj, "song_id"].tolist()
    )
    songs_same_genre = songs_same_genre[
        ~songs_same_genre["id"].isin(rated_songs)
    ].copy()
    
    if songs_same_genre.empty:
        continue
    
    # Compute distance to user’s preference
    diffs = songs_same_genre[feat_cols].values - user_pref.values
    songs_same_genre["distance"] = np.linalg.norm(diffs, axis=1)
    
    # Pick N least similar (largest distance)
    most_dissimilar = songs_same_genre.sort_values("distance", ascending=False).head(N)
    
    # Keep only the required columns
    for _, row in most_dissimilar.iterrows():
        rows.append({
            "subject": subj,
            "genre_allmusic": row["genre_allmusic"],
            "trackname": row["trackname"],
            "bucket": "same_genre_dissimilar"
        })

# Final dataframe
recs_same_genre_dissimilar = pd.DataFrame(rows)

# %%
rows = []
for subj in analysis_df["subject"].unique():
    
    # Subject's preferred genre
    preferred_genre = analysis_df.loc[
        analysis_df["subject"] == subj, "preferred_genre"
    ].iloc[0]
    
    # Subject's like profile
    user_pref = analysis_df.loc[
        analysis_df["subject"] == subj, like_cols
    ].iloc[0]
    
    # Songs in any genre except  the preferred one
    songs_diff_genre = df_songs[df_songs["genre_allmusic"] != preferred_genre].copy()
    
    # Remove songs already rated by this subject
    rated_songs = set(
        analysis_df.loc[analysis_df["subject"] == subj, "song_id"].tolist()
    )
    songs_diff_genre = songs_diff_genre[
        ~songs_diff_genre["id"].isin(rated_songs)
    ].copy()
    
    # Compute distance to subject’s preference
    diffs = songs_diff_genre[feat_cols].values - user_pref.values
    songs_diff_genre["distance"] = np.linalg.norm(diffs, axis=1)
    
    # Take N least similar songs (largest distance)
    most_dissimilar = songs_diff_genre.sort_values("distance", ascending=False).head(N)
    
    # Keep only requested columns
    for _, row in most_dissimilar.iterrows():
        rows.append({
            "subject": subj,
            "genre_allmusic": row["genre_allmusic"],
            "trackname": row["trackname"],
            "bucket": "diff_genre_dissimilar"
        })

# Final dataframe
recs_diff_genre_dissimilar = pd.DataFrame(rows)

# %% [markdown]
# Now that we have all these, we put them together in a single dataframe

# %%
all_recs = pd.concat(
    [
        recs_same_genre_similar,
        recs_same_genre_dissimilar,
        recs_diff_genre_similar,
        recs_diff_genre_dissimilar,
    ],
    ignore_index=True
)
#sort all_recs
all_recs = all_recs.sort_values(
    by=["subject", "bucket"],
    key=lambda x: x.map({
        "same_genre_similar": 0,
        "same_genre_dissimilar": 1,
        "diff_genre_similar": 2,
        "diff_genre_dissimilar": 3
    }) if x.name == "bucket" else x
).reset_index(drop=True)
all_recs.head()
# Out:
#   subject genre_allmusic             trackname                 bucket
# 0    S105       pop-rock         Runaway Train     same_genre_similar
# 1    S105       pop-rock              Nutshell     same_genre_similar
# 2    S105       pop-rock       I'm a Slave 4 U  same_genre_dissimilar
# 3    S105       pop-rock   Message In A Bottle  same_genre_dissimilar
# 4    S105        country  Three Wooden Crosses     diff_genre_similar

# %%
# Merge to add email per subject
all_recs_with_email = all_recs.merge(contact_group2, on="subject", how="left")

# Remove genre column
all_recs_with_email = all_recs_with_email.drop(columns=["genre_allmusic"])

all_recs_with_email
# Out:
#        subject                                          trackname  \
# 0         S105                                      Runaway Train
# 1         S105                                           Nutshell
# 2         S105                                    I'm a Slave 4 U
# 3         S105                                Message In A Bottle
# 4         S105                               Three Wooden Crosses
# 5         S105                                            Trigger
# 6         S105  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 7         S105  Water Music Suite No. 1 In F, HWV 348: 2. Adag...
# 8         S106  More Than A Woman - From "Saturday Night Fever...
# 9         S106                                           Nutshell
# 10        S106                                    I'm a Slave 4 U
# 11        S106                       Beast Of Burden - Remastered
# 12        S106                             Deeper Than the Holler
# 13        S106                               Three Wooden Crosses
# 14        S106  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 15        S106  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 16        S107  More Than A Woman - From "Saturday Night Fever...
# 17        S107                                      Runaway Train
# 18        S107                                           Nutshell
# 19        S107                                    I'm a Slave 4 U
# 20        S107                                       Losing Sleep
# 21        S107                                  Rockin' That Shit
# 22        S107  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 23        S107  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 24        S128                                           Nutshell
# 25        S128  More Than A Woman - From "Saturday Night Fever...
# 26        S128                                    I'm a Slave 4 U
# 27        S128                       Beast Of Burden - Remastered
# 28        S128                                            Trigger
# 29        S128                               Three Wooden Crosses
# 30        S128  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 31        S128  Water Music Suite No. 1 In F, HWV 348: 2. Adag...
# 32        S129              Young, Wild & Free (feat. Bruno Mars)
# 33        S129  Get Money (feat. Junior M.A.F.I.A.) - 2007 Rem...
# 34        S129                          Bad Boy (with Young Thug)
# 35        S129  Everyday (feat. Rod Stewart, Miguel & Mark Ron...
# 36        S129                                  Rockin' That Shit
# 37        S129  More Than A Woman - From "Saturday Night Fever...
# 38        S129  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 39        S129  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 40        S137                              Antidote - Radio Edit
# 41        S137                                         The Prince
# 42        S137                                            Falaise
# 43        S137                                            Colours
# 44        S137  Get Money (feat. Junior M.A.F.I.A.) - 2007 Rem...
# 45        S137                                  While We're Young
# 46        S137  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 47        S137  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 48        S139                                        Purple Haze
# 49        S139                                      Runaway Train
# 50        S139                                    I'm a Slave 4 U
# 51        S139                                         Centerfold
# 52        S139                                         The Prince
# 53        S139  All I Do Is Win (feat. T-Pain, Ludacris, Snoop...
# 54        S139  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 55        S139  Water Music Suite No. 1 In F, HWV 348: 2. Adag...
# 56        S140  Requiem in D Minor, K. 626: 3. Sequentia: Dies...
# 57        S140                                  Danza Hungara Nº5
# 58        S140  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 59        S140  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 60        S140                                              IZ-US
# 61        S140                               Three Wooden Crosses
# 62        S140                                    I'm a Slave 4 U
# 63        S140                       Beast Of Burden - Remastered
# 64        S148                                      Runaway Train
# 65        S148                                She Sells Sanctuary
# 66        S148                                    I'm a Slave 4 U
# 67        S148                       Beast Of Burden - Remastered
# 68        S148              Young, Wild & Free (feat. Bruno Mars)
# 69        S148                                       Losing Sleep
# 70        S148  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 71        S148  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 72        S150                                         Be My Baby
# 73        S150                                 A Teenager In Love
# 74        S150                                     A Song for You
# 75        S150              Un-Break My Heart - Classic Radio Mix
# 76        S150                                       Losing Sleep
# 77        S150                                               Babe
# 78        S150  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 79        S150  Cello Concerto in E Minor, Op.85 (1997 - Remas...
#
Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 159       S185  Water Music Suite No. 1 In F, HWV 348: 2. Adag...
# 160       S186                                      Runaway Train
# 161       S186                          Ramble On - 1990 Remaster
# 162       S186                                           Nutshell
# 163       S186                       Beast Of Burden - Remastered
# 164       S186                                               Babe
# 165       S186         I Need a Girl (Pt. 1) [feat. Usher & Loon]
# 166       S186  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 167       S186  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 168         S9                                  Danza Hungara Nº5
# 169         S9  Serenade for Strings in C major, Op. 48: II. W...
# 170         S9  Cello Concerto in E Minor, Op.85 (1997 - Remas...
# 171         S9  Water Music Suite No. 1 In F, HWV 348: 2. Adag...
# 172         S9                               Three Wooden Crosses
# 173         S9                                            Trigger
# 174         S9                       Beast Of Burden - Remastered
# 175         S9  Get Money (feat. Junior M.A.F.I.A.) - 2007 Rem...
# 176  anonymous                                Message In A Bottle
# 177  anonymous                                         Centerfold
# 178  anonymous                                She Sells Sanctuary
# 179  anonymous                                        Purple Haze
# 180  anonymous         I Need a Girl (Pt. 1) [feat. Usher & Loon]
# 181  anonymous                                  Raised on Country
# 182  anonymous  Bassoon Concerto in B-Flat Major, K. 191: II. ...
# 183  anonymous  Cello Concerto in E Minor, Op.85 (1997 - Remas...
#
#                     bucket                                 email
# 0       same_genre_similar               kittytail@hotmail.co.uk
# 1       same_genre_similar               kittytail@hotmail.co.uk
# 2    same_genre_dissimilar               kittytail@hotmail.co.uk
# 3    same_genre_dissimilar               kittytail@hotmail.co.uk
# 4       diff_genre_similar               kittytail@hotmail.co.uk
# 5       diff_genre_similar               kittytail@hotmail.co.uk
# 6    diff_genre_dissimilar               kittytail@hotmail.co.uk
# 7    diff_genre_dissimilar               kittytail@hotmail.co.uk
# 8       same_genre_similar               harryhall3698@gmail.com
# 9       same_genre_similar               harryhall3698@gmail.com
# 10   same_genre_dissimilar               harryhall3698@gmail.com
# 11   same_genre_dissimilar               harryhall3698@gmail.com
# 12      diff_genre_similar               harryhall3698@gmail.com
# 13      diff_genre_similar               harryhall3698@gmail.com
# 14   diff_genre_dissimilar               harryhall3698@gmail.com
# 15   diff_genre_dissimilar               harryhall3698@gmail.com
# 16      same_genre_similar  l.j.vanvoorden@tilburguniversity.edu
# 17      same_genre_similar  l.j.vanvoorden@tilburguniversity.edu
# 18   same_genre_dissimilar  l.j.vanvoorden@tilburguniversity.edu
# 19   same_genre_dissimilar  l.j.vanvoorden@tilburguniversity.edu
# 20      diff_genre_similar  l.j.vanvoorden@tilburguniversity.edu
# 21      diff_genre_similar  l.j.vanvoorden@tilburguniversity.edu
# 22   diff_genre_dissimilar  l.j.vanvoorden@tilburguniversity.edu
# 23   diff_genre_dissimilar  l.j.vanvoorden@tilburguniversity.edu
# 24      same_genre_similar    r.s.kramer_1@tilburguniversity.edu
# 25      same_genre_similar    r.s.kramer_1@tilburguniversity.edu
# 26   same_genre_dissimilar    r.s.kramer_1@tilburguniversity.edu
# 27   same_genre_dissimilar    r.s.kramer_1@tilburguniversity.edu
# 28      diff_genre_similar    r.s.kramer_1@tilburguniversity.edu
# 29      diff_genre_similar    r.s.kramer_1@tilburguniversity.edu
# 30   diff_genre_dissimilar    r.s.kramer_1@tilburguniversity.edu
# 31   diff_genre_dissimilar    r.s.kramer_1@tilburguniversity.edu
# 32      same_genre_similar    j.m.spuesens@tilburguniversity.edu
# 33      same_genre_similar    j.m.spuesens@tilburguniversity.edu
# 34   same_genre_dissimilar    j.m.spuesens@tilburguniversity.edu
# 35   same_genre_dissimilar    j.m.spuesens@tilburguniversity.edu
# 36      diff_genre_similar    j.m.spuesens@tilburguniversity.edu
# 37      diff_genre_similar    j.m.spuesens@tilburguniversity.edu
# 38   diff_genre_dissimilar    j.m.spuesens@tilburguniversity.edu
# 39   diff_genre_dissimilar    j.m.spuesens@tilburguniversity.edu
# 40      same_genre_similar                Alettakramer@gmail.com
# 41      same_genre_similar                Alettakramer@gmail.com
# 42   same_genre_dissimilar                Alettakramer@gmail.com
# 43   same_genre_dissimilar                Alettakramer@gmail.com
# 44      diff_genre_similar                Alettakramer@gmail.com
# 45      diff_genre_similar                Alettakramer@gmail.com
# 46   diff_genre_dissimilar                Alettakramer@gmail.com
# 47   diff_genre_dissimilar                Alettakramer@gmail.com
# 48      same_genre_similar                   R.kramer@genexis.eu
# 49      same_genre_similar                   R.kramer@genexis.eu
# 50   same_genre_dissimilar                   R.kramer@genexis.eu
# 51   same_genre_dissimilar                   R.kramer@genexis.eu
# 52      diff_genre_similar                   R.kramer@genexis.eu
# 53      diff_genre_similar                   R.kramer@genexis.eu
# 54   diff_genre_dissimilar                   R.kramer@genexis.eu
# 55   diff_genre_dissimilar                   R.kramer@genexis.eu
# 56      same_genre_similar             Kramer.marijke@kpnmail.nl
# 57      same_genre_similar             Kramer.marijke@kpnmail.nl
# 58   same_genre_dissimilar             Kramer.marijke@kpnmail.nl
# 59   same_genre_dissimilar             Kramer.marijke@kpnmail.nl
# 60      diff_genre_similar             Kramer.marijke@kpnmail.nl
# 61      diff_genre_similar             Kramer.marijke@kpnmail.nl
# 62   diff_genre_dissimilar             Kramer.marijke@kpnmail.nl
# 63   diff_genre_dissimilar             Kramer.marijke@kpnmail.nl
# 64      same_genre_similar          roosvanvoorden2004@gmail.com
# 65      same_genre_similar          roosvanvoorden2004@gmail.com
# 66   same_genre_dissimilar          roosvanvoorden2004@gmail.com
# 67   same_genre_dissimilar          roosvanvoorden2004@gmail.com
# 68      diff_genre_similar          roosvanvoorden2004@gmail.com
# 69      diff_genre_similar          roosvanvoorden2004@gmail.com
# 70   diff_genre_dissimilar          roosvanvoorden2004@gmail.com
# 71   diff_genre_dissimilar          roosvanvoorden2004@gmail.com
# 72      same_genre_similar        r.w.mast@tilburguniversity.edu
# 73      same_genre_similar        r.w.mast@tilburguniversity.edu
# 74   same_genre_dissimilar        r.w.mast@tilburguniversity.edu
# 75   same_genre_dissimilar        r.w.mast@tilburguniversity.edu
# 76      diff_genre_similar        r.w.mast@tilburguniversity.edu
# 77      diff_genre_similar        r.w.mast@tilburguniversity.edu
# 78   diff_genre_dissimilar        r.w.mast@tilburguniversity.edu
# 79   diff_genre_dissimilar        r.w.mast@tilburguniversity.edu
# 80      same_genre_similar                nijdamgerben@gmail.com
# 81      same_genre_similar                nijdamgerben@gmail.com
# 82   same_genre_dissimilar                nijdamgerben@gmail.com
# 83   same_genre_dissimilar                nijdamgerben@gmail.com
# 84      diff_genre_similar                nijdamgerben@gmail.com
# 85      diff_genre_similar                nijdamgerben@gmail.com
# 86   diff_genre_dissimilar                nijdamgerben@gmail.com
# 87   diff_genre_dissimilar                nijdamgerben@gmail.com
# 88      same_genre_similar     f.vdnbrekel@tilburguniversity.edu
# 89      same_genre_similar     f.vdnbrekel@tilburguniversity.edu
# 90   same_genre_dissimilar     f.vdnbrekel@tilburguniversity.edu
# 91   same_genre_dissimilar     f.vdnbrekel@tilburguniversity.edu
# 92      diff_genre_similar     f.vdnbrekel@tilburguniversity.edu
# 93      diff_genre_similar     f.vdnbrekel@tilburguniversity.edu
# 94   diff_genre_dissimilar     f.vdnbrekel@tilburguniversity.edu
# 95   diff_genre_dissimilar     f.vdnbrekel@tilburguniversity.edu
# 96      same_genre_similar                  jackmeijer28@live.nl
# 97      same_genre_similar                  jackmeijer28@live.nl
# 98   same_genre_dissimilar                  jackmeijer28@live.nl
# 99   same_genre_dissimilar                  jackmeijer28@live.nl
# 100     diff_genre_similar                  jackmeijer28@live.nl
# 101     diff_genre_similar                  jackmeijer28@live.nl
# 102  diff_genre_dissimilar                  jackmeijer28@live.nl
# 103  diff_genre_dissimilar                  jackmeijer28@live.nl
# 104     same_genre_similar            ambervdheuvel007@gmail.com
# 105     same_genre_similar            ambervdheuvel007@gmail.com
# 106  same_genre_dissimilar            ambervdheuvel007@gmail.com
# 107  same_genre_dissimilar            ambervdheuvel007@gmail.com
# 108     diff_genre_similar            ambervdheuvel007@gmail.com
# 109     diff_genre_similar            ambervdheuvel007@gmail.com
# 110  diff_genre_dissimilar            ambervdheuvel007@gmail.com
# 111  diff_genre_dissimilar            ambervdheuvel007@gmail.com
# 112     same_genre_similar                   tranjaney@gmail.com
# 113     same_genre_similar                   tranjaney@gmail.com
# 114  same_genre_dissimilar                   tranjaney@gmail.com
# 115  same_genre_dissimilar                   tranjaney@gmail.com
# 116     diff_genre_similar                   tranjaney@gmail.com
# 117     diff_genre_similar                   tranjaney@gmail.com
# 118  diff_genre_dissimilar                   tranjaney@gmail.com
# 119  diff_genre_dissimilar                   tranjaney@gmail.com
# 120     same_genre_similar             bloemvdbrekel@outlook.com
# 121     same_genre_similar             bloemvdbrekel@outlook.com
# 122  same_genre_dissimilar             bloemvdbrekel@outlook.com
# 123  same_genre_dissimilar             bloemvdbrekel@outlook.com
# 124     diff_genre_similar             bloemvdbrekel@outlook.com
# 125     diff_genre_similar             bloemvdbrekel@outlook.com
# 126  diff_genre_dissimilar             bloemvdbrekel@outlook.com
# 127  diff_genre_dissimilar             bloemvdbrekel@outlook.com
# 128     same_genre_similar            woutvdveldenspam@gmail.com
# 129     same_genre_similar            woutvdveldenspam@gmail.com
# 130  same_genre_dissimilar            woutvdveldenspam@gmail.com
# 131  same_genre_dissimilar            woutvdveldenspam@gmail.com
# 132     diff_genre_similar            woutvdveldenspam@gmail.com
# 133     diff_genre_similar            woutvdveldenspam@gmail.com
# 134  diff_genre_dissimilar            woutvdveldenspam@gmail.com
# 135  diff_genre_dissimilar            woutvdveldenspam@gmail.com
# 136     same_genre_similar                    Veldenk2@gmail.com
# 137     same_genre_similar                    Veldenk2@gmail.com
# 138  same_genre_dissimilar                    Veldenk2@gmail.com
# 139  same_genre_dissimilar                    Veldenk2@gmail.com
# 140     diff_genre_similar                    Veldenk2@gmail.com
# 141     diff_genre_similar                    Veldenk2@gmail.com
# 142  diff_genre_dissimilar                    Veldenk2@gmail.com
# 143  diff_genre_dissimilar                    Veldenk2@gmail.com
# 144     same_genre_similar                   feevdbrekel@live.nl
# 145     same_genre_similar                   feevdbrekel@live.nl
# 146  same_genre_dissimilar                   feevdbrekel@live.nl
# 147  same_genre_dissimilar                   feevdbrekel@live.nl
# 148     diff_genre_similar                   feevdbrekel@live.nl
# 149     diff_genre_similar                   feevdbrekel@live.nl
# 150  diff_genre_dissimilar                   feevdbrekel@live.nl
# 151  diff_genre_dissimilar                   feevdbrekel@live.nl
# 152     same_genre_similar          julemackenbach2002@gmail.com
# 153     same_genre_similar          julemackenbach2002@gmail.com
# 154  same_genre_dissimilar          julemackenbach2002@gmail.com
# 155  same_genre_dissimilar          julemackenbach2002@gmail.com
# 156     diff_genre_similar          julemackenbach2002@gmail.com
# 157     diff_genre_similar          julemackenbach2002@gmail.com
# 158  diff_genre_dissimilar          julemackenbach2002@gmail.com
# 159  diff_genre_dissimilar          julemackenbach2002@gmail.com
# 160     same_genre_similar            mielvandenbrekel@gmail.com
# 161     same_genre_similar            mielvandenbrekel@gmail.com
# 162  same_genre_dissimilar            mielvandenbrekel@gmail.com
# 163  same_genre_dissimilar            mielvandenbrekel@gmail.com
# 164     diff_genre_similar            mielvandenbrekel@gmail.com
# 165     diff_genre_similar            mielvandenbrekel@gmail.com
# 166  diff_genre_dissimilar            mielvandenbrekel@gmail.com
# 167  diff_genre_dissimilar            mielvandenbrekel@gmail.com
# 168     same_genre_similar       f.franken@tilburguniversity.edu
# 169     same_genre_similar       f.franken@tilburguniversity.edu
# 170  same_genre_dissimilar       f.franken@tilburguniversity.edu
# 171  same_genre_dissimilar       f.franken@tilburguniversity.edu
# 172     diff_genre_similar       f.franken@tilburguniversity.edu
# 173     diff_genre_similar       f.franken@tilburguniversity.edu
# 174  diff_genre_dissimilar       f.franken@tilburguniversity.edu
# 175  diff_genre_dissimilar       f.franken@tilburguniversity.edu
# 176     same_genre_similar             pieter.drabbe@hotmail.com
# 177     same_genre_similar             pieter.drabbe@hotmail.com
# 178  same_genre_dissimilar             pieter.drabbe@hotmail.com
# 179  same_genre_dissimilar             pieter.drabbe@hotmail.com
# 180     diff_genre_similar             pieter.drabbe@hotmail.com
# 181     diff_genre_similar             pieter.drabbe@hotmail.com
# 182  diff_genre_dissimilar             pieter.drabbe@hotmail.com
# 183  diff_genre_dissimilar             pieter.drabbe@hotmail.com
